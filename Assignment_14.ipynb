# %% [markdown]
# # 1. What does RGBA stand for?

# %%
RGBA(Red-Green-Blue-Alpha)

# %% [markdown]
# # 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from PIL import Image
filename = "C:\\file\\dogs.jpeg"
with Image.open(filename) as img:
     img.load()

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
from PIL import ImageColor
ImageColor.getcolor('red', 'RGBA')
# Out:
# (255, 0, 0, 255)

# %%
ImageColor.getcolor('Black', 'RGBA')
# Out:
# (0, 0, 0, 255)

# %% [markdown]
# # 3. What is a box tuple, and how does it work?

# %% [raw]
# Many of Pillow's functions and methods take a box tuple argument. This means Pillow is expecting a tuple of four integer coordinates that represent a rectangular region in an image. The four integers are, in order, as follows: Left The x-coordinate of the leftmost edge of the box.

# %% [markdown]
# # 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
myImg = Image.open('C:\\file\\images.jpg')
w,h = myImg.size
w,h
myImg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=239x211 at 0x26E8619BD60>

# %% [markdown]
# # 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %% [raw]
# croppedIm = myImg.crop((0, 50, 50, 50))
# croppedIm

# %% [markdown]
# # 6. After making changes to an Image object, how could you save it as an image file?

# %% [raw]
# croppedIm.save('C:\\file\\cropped.png')

# %% [markdown]
# # 7. What module contains Pillow’s shape-drawing code?

# %%
The ImageDraw module contains code to draw on images

# %% [markdown]
# # 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [raw]
# ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image object to the ImageDraw.Draw() function
